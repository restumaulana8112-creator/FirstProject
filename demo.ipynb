# %%
nama = input("Masukkan nama Anda: ")
print(f"Hello, {nama}! + Selamat datang di program kami!")
# Out:
# Hello, Restu! + Selamat datang di program kami!

# %%
NamaLengkap = "Restu Ihsan Maulana"
NamaPanggilan = "Restu"
Umur = 16

print("Nama lengkap saya adalah " + NamaLengkap + " dan kamu bisa memanggil saya " + NamaPanggilan)
# Out:
# Nama lengkap saya adalah Restu Ihsan Maulana dan kamu bisa memanggil saya Restu
